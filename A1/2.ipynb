# %% [markdown]
# **Question 2**
#
# [Google Colab](https://colab.research.google.com/drive/1-IX7Ck4Cwp6p9sIK2lo1rFM5tNKWLkA4?usp=sharing)

# %%
# Clone necessary repositories
# !git clone https://github.com/zhouhaoyi/Informer2020.git
# !git clone https://github.com/zhouhaoyi/ETDataset.git
# !ls
# Out:
# Cloning into 'Informer2020'...
# remote: Enumerating objects: 576, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 576 (delta 199), reused 188 (delta 188), pack-reused 354
# Receiving objects: 100% (576/576), 6.48 MiB | 17.36 MiB/s, done.
# Resolving deltas: 100% (336/336), done.
# Cloning into 'ETDataset'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 187 (delta 25), reused 20 (delta 20), pack-reused 159
# Receiving objects: 100% (187/187), 3.86 MiB | 12.45 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# ETDataset  Informer2020  sample_data

# %%
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

# %%
# Import required modules and libraries
from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch

# %%
# Define configuration settings
args = dotdict()
args.model = 'informer'
args.data = 'ETTh1'
args.root_path = './ETDataset/ETT-small/'
args.data_path = 'ETTh1.csv'
args.features = 'S'
args.target = 'OT'
args.freq = 'h'
args.checkpoints = './informer_checkpoints'

args.seq_len = 96
args.label_len = 48
args.pred_len = 24

args.enc_in = 1
args.dec_in = 1
args.c_out = 1
args.factor = 5
args.d_model = 512
args.n_heads = 8
args.e_layers = 2
args.d_layers = 1
args.d_ff = 2048
args.dropout = 0.05
args.attn = 'prob'
args.embed = 'timeF'
args.activation = 'gelu'
args.distil = True
args.output_attention = False
args.mix = True
args.padding = 0
args.freq = 'h'

args.batch_size = 32
args.learning_rate = 0.0001
args.loss = 'mse'
args.lradj = 'type1'
args.use_amp = False

args.num_workers = 0
args.itr = 1
args.train_epochs = 6
args.patience = 3
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

# %%
# Check if GPU is available and whether to use it
args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.devices = args.devices.replace(' ','')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

# %%
# Define data parser for specific datasets
data_parser = {
    'ETTh1':{'data':'ETTh1.csv','T':'OT','M':[1,1,1],'S':[1,1,1],'MS':[1,1,1]},
}

# Update args based on selected dataset
if args.data in data_parser.keys():
    data_info = data_parser[args.data]
    args.data_path = data_info['data']
    args.target = data_info['T']
    args.enc_in, args.dec_in, args.c_out = data_info[args.features]

# %%
# Store original frequency and update it
args.detail_freq = args.freq
args.freq = args.freq[-1:]

# %%
# Print experiment parameters
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'ETTh1', 'root_path': './ETDataset/ETT-small/', 'data_path': 'ETTh1.csv', 'features': 'S', 'target': 'OT', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 96, 'label_len': 48, 'pred_len': 24, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 32, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': True, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}

# %%
# Define the Experiment class as Exp
Exp = Exp_Informer

# %%
# Lists to store MSE and MAE values
mse_values = []
mae_values = []

# %%
# Iterate over multiple experiments
for ii in range(args.itr):
    setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}'.format(args.model, args.data, args.features,
                args.seq_len, args.label_len, args.pred_len,
                args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii)

    # Create an instance of Exp with args
    exp = Exp(args)

    # Training phase
    print(f'---------------------- Start training: {setting} ---------------------->')
    exp.train(setting)

    # Testing phase
    print(f'---------------------- Testing: {setting} ----------------------')
    exp.test(setting)

    torch.cuda.empty_cache()
# Out:
# Use GPU: cuda:0
# ---------------------- Start training: informer_ETTh1_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ---------------------->
# train 8521
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1411325
# 	speed: 0.1546s/iter; left time: 231.4593s
# 	iters: 200, epoch: 1 | loss: 0.2526858
# 	speed: 0.0673s/iter; left time: 94.0005s
# Epoch: 1 cost time: 25.833764791488647
# Epoch: 1, Steps: 266 | Train Loss: 0.1808954 Vali Loss: 0.0750277 Test Loss: 0.1169866
# Validation loss decreased (inf --> 0.075028).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.1314837
# 	speed: 0.1576s/iter; left time: 194.0659s
# 	iters: 200, epoch: 2 | loss: 0.0937599
# 	speed: 0.0688s/iter; left time: 77.8269s
# Epoch: 2 cost time: 18.11609172821045
# Epoch: 2, Steps: 266 | Train Loss: 0.0946675 Vali Loss: 0.0641157 Test Loss: 0.1438152
# Validation loss decreased (0.075028 --> 0.064116).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0668441
# 	speed: 0.1629s/iter; left time: 157.2339s
# 	iters: 200, epoch: 3 | loss: 0.0706372
# 	speed: 0.0727s/iter; left time: 62.8509s
# Epoch: 3 cost time: 18.89661407470703
# Epoch: 3, Steps: 266 | Train Loss: 0.0738668 Vali Loss: 0.0688365 Test Loss: 0.1263893
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0407075
# 	speed: 0.1616s/iter; left time: 112.9698s
# 	iters: 200, epoch: 4 | loss: 0.0488751
# 	speed: 0.0705s/iter; left time: 42.2060s
# Epoch: 4 cost time: 18.72323489189148
# Epoch: 4, Steps: 266 | Train Loss: 0.0650034 Vali Loss: 0.0761610 Test Loss: 0.2078641
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.0648217
# 	speed: 0.1641s/iter; left time: 71.0618s
# 	iters: 200, epoch: 5 | loss: 0.0697530
# 	speed: 0.0713s/iter; left time: 23.7395s
# Epoch: 5 cost time: 19.014586448669434
# Epoch: 5, Steps: 266 | Train Loss: 0.0594499 Vali Loss: 0.0731913 Test Loss: 0.1543898
# EarlyStopping counter: 3 out of 3
# Early stopping
# ---------------------- Testing: informer_ETTh1_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ----------------------
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.14341051876544952, mae:0.3226287066936493

# %%
import os

# Load a specific experiment setting for prediction
setting = 'informer_ETTh1_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'

# %%
exp = Exp(args)

# Generate predictions for the loaded setting
exp.predict(setting, True)
# Out:
# Use GPU: cuda:0
# pred 1

# %%
# Import necessary libraries for plotting
import numpy as np
import matplotlib.pyplot as plt

# Load metrics for the specified setting
metrics_path = './results/' + setting + '/metrics.npy'
metrics = np.load(metrics_path)

# Append metrics values to respective lists
mae_values.append(metrics[0])
mse_values.append(metrics[1])

# Load real predictions for plotting
prediction = np.load('./results/'+setting+'/real_prediction.npy')
prediction.shape

plt.figure()
plt.plot(prediction[0, :, -1])
plt.show()

# %%
# Define a function to generate predictions
def predict(exp, setting, load=False):
    pred_data, pred_loader = exp._get_data(flag='pred')

    # Load the best model if specified
    if load:
        path = os.path.join(exp.args.checkpoints, setting)
        best_model_path = path+'/'+'checkpoint.pth'
        exp.model.load_state_dict(torch.load(best_model_path))

    # Set the model to evaluation mode
    exp.model.eval()

    preds = []

    # Iterate over prediction loader
    for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(pred_loader):
        batch_x = batch_x.float().to(exp.device)
        batch_y = batch_y.float()
        batch_x_mark = batch_x_mark.float().to(exp.device)
        batch_y_mark = batch_y_mark.float().to(exp.device)

        # Define the decoding input based on padding
        if exp.args.padding==0:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        elif exp.args.padding==1:
            dec_inp = torch.ones([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        else:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        dec_inp = torch.cat([batch_y[:,:exp.args.label_len,:], dec_inp], dim=1).float().to(exp.device)

        # Apply automatic mixed precision if specified
        if exp.args.use_amp:
            with torch.cuda.amp.autocast():
                if exp.args.output_attention:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
                else:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        else:
            if exp.args.output_attention:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
            else:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)

        # Extract target dimensions based on features
        f_dim = -1 if exp.args.features=='MS' else 0
        batch_y = batch_y[:,-exp.args.pred_len:,f_dim:].to(exp.device)

        # Convert predictions to numpy array
        pred = outputs.detach().cpu().numpy()#.squeeze()

        # Append predictions to the list
        preds.append(pred)

    # Convert predictions to numpy array and reshape
    preds = np.array(preds)
    preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])

    # Define folder path to store predictions
    folder_path = './results/' + setting +'/'
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Save real predictions to a file
    np.save(folder_path+'real_prediction.npy', preds)

    return preds

# %%
# Generate predictions for a specific setting
prediction = predict(exp, setting, True)
# Out:
# pred 1

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

# %%
# Import necessary modules for data loading
from data.data_loader import Dataset_Pred
from torch.utils.data import DataLoader

# %%
# Define data set and data loader for prediction
Data = Dataset_Pred
timeenc = 0 if args.embed!='timeF' else 1
flag = 'pred'; shuffle_flag = False; drop_last = False; batch_size = 1

freq = args.detail_freq

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    target=args.target,
    timeenc=timeenc,
    freq=freq
)

data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
# Print lengths of data set and data loader
len(data_set), len(data_loader)
# Out:
# (1, 1)

# %%
# Load predictions and ground truth values
preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

# Print shapes of predictions and ground truth
preds.shape, trues.shape
# Out:
# ((2848, 24, 1), (2848, 24, 1))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Draw OT prediction
plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# Draw HUFL prediction
plt.figure()
plt.plot(trues[0,:,0], label='GroundTruth')
plt.plot(preds[0,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Load predictions for the current setting and plot
exp.predict(setting, True)
prediction = np.load('./results/' + setting + '/real_prediction.npy')

# Plot predictions
plt.figure()
plt.plot(prediction[0, :, -1])
plt.show()
# Out:
# pred 1

# %%
# Update prediction length
args.pred_len = 48

# Define data parser for specific datasets
data_parser = {
    'ETTh1':{'data':'ETTh1.csv','T':'OT','M':[1,1,1],'S':[1,1,1],'MS':[1,1,1]},
}

# Update args based on selected dataset
if args.data in data_parser.keys():
    data_info = data_parser[args.data]
    args.data_path = data_info['data']
    args.target = data_info['T']
    args.enc_in, args.dec_in, args.c_out = data_info[args.features]

# Store original frequency and update it
args.detail_freq = args.freq
args.freq = args.freq[-1:]

# Print experiment parameters
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'ETTh1', 'root_path': './ETDataset/ETT-small/', 'data_path': 'ETTh1.csv', 'features': 'S', 'target': 'OT', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 96, 'label_len': 48, 'pred_len': 48, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 32, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': True, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}

# %%
# Define the Experiment class as Exp
Exp = Exp_Informer

# %%
# Iterate over multiple experiments
for ii in range(args.itr):
    setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}'.format(args.model, args.data, args.features,
                args.seq_len, args.label_len, args.pred_len,
                args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii)

    # Create an instance of Exp with args
    exp = Exp(args)

    # Training phase
    print(f'---------------------- Start training: {setting} ---------------------->')
    exp.train(setting)

    # Testing phase
    print(f'---------------------- Testing: {setting} ----------------------')
    exp.test(setting)

    torch.cuda.empty_cache()
# Out:
# Use GPU: cuda:0
# ---------------------- Start training: informer_ETTh1_ftS_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ---------------------->
# train 8497
# val 2833
# test 2833
# 	iters: 100, epoch: 1 | loss: 0.1703198
# 	speed: 0.0791s/iter; left time: 118.0112s
# 	iters: 200, epoch: 1 | loss: 0.2058648
# 	speed: 0.0797s/iter; left time: 110.8493s
# Epoch: 1 cost time: 21.08319902420044
# Epoch: 1, Steps: 265 | Train Loss: 0.1933783 Vali Loss: 0.1272786 Test Loss: 0.2191207
# Validation loss decreased (inf --> 0.127279).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.1129774
# 	speed: 0.1856s/iter; left time: 227.4908s
# 	iters: 200, epoch: 2 | loss: 0.1263757
# 	speed: 0.0803s/iter; left time: 90.4280s
# Epoch: 2 cost time: 21.261298656463623
# Epoch: 2, Steps: 265 | Train Loss: 0.1240409 Vali Loss: 0.1001090 Test Loss: 0.1868236
# Validation loss decreased (0.127279 --> 0.100109).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0966709
# 	speed: 0.1878s/iter; left time: 180.4672s
# 	iters: 200, epoch: 3 | loss: 0.0802276
# 	speed: 0.0809s/iter; left time: 69.6673s
# Epoch: 3 cost time: 21.45624613761902
# Epoch: 3, Steps: 265 | Train Loss: 0.0916022 Vali Loss: 0.1272296 Test Loss: 0.1532634
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0981250
# 	speed: 0.1875s/iter; left time: 130.5051s
# 	iters: 200, epoch: 4 | loss: 0.0723176
# 	speed: 0.0807s/iter; left time: 48.1020s
# Epoch: 4 cost time: 21.43173837661743
# Epoch: 4, Steps: 265 | Train Loss: 0.0793785 Vali Loss: 0.1326021 Test Loss: 0.2402115
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.0523476
# 	speed: 0.1861s/iter; left time: 80.2297s
# 	iters: 200, epoch: 5 | loss: 0.0802156
# 	speed: 0.0805s/iter; left time: 26.6540s
# Epoch: 5 cost time: 21.33984875679016
# Epoch: 5, Steps: 265 | Train Loss: 0.0729870 Vali Loss: 0.1223274 Test Loss: 0.1727771
# EarlyStopping counter: 3 out of 3
# Early stopping
# ---------------------- Testing: informer_ETTh1_ftS_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ----------------------
# test 2833
# test shape: (88, 32, 48, 1) (88, 32, 48, 1)
# test shape: (2816, 48, 1) (2816, 48, 1)
# mse:0.1869170218706131, mae:0.3665928840637207

# %%
import os

# Load a specific experiment setting for prediction
setting = 'informer_ETTh1_ftS_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'

# %%
exp = Exp(args)

# Generate predictions for the loaded setting
exp.predict(setting, True)
# Out:
# Use GPU: cuda:0
# pred 1

# %%
# Import necessary libraries for plotting
import numpy as np
import matplotlib.pyplot as plt

# Load metrics for the specified setting
metrics_path = './results/' + setting + '/metrics.npy'
metrics = np.load(metrics_path)

# Append metrics values to respective lists
mae_values.append(metrics[0])
mse_values.append(metrics[1])

# Load real predictions for plotting
prediction = np.load('./results/'+setting+'/real_prediction.npy')
prediction.shape

plt.figure()
plt.plot(prediction[0, :, -1])
plt.show()

# %%
# Display the results in a table
from tabulate import tabulate

# Print the dataset name
print(args.data)
time_intervals = [24, 48]

# Define paper metrics values for comparison
paper_mse_values = [0.098, 0.158]
paper_mae_values = [0.247, 0.319]

# Create a table with metric values for both paper and the current experiment
data = [
    ["Metric", "Paper MSE", "My MSE", "Paper MAE", "My MAE"],
    [time_intervals[0], paper_mse_values[0], mse_values[0], paper_mae_values[0], mae_values[0]],
    [time_intervals[1], paper_mse_values[1], mse_values[1], paper_mae_values[1], mae_values[1]],
]

# Generate the table with headers and specified format
table = tabulate(data, headers="firstrow", tablefmt="grid")
print(table)
# Out:
# ETTh1
# +----------+-------------+----------+-------------+----------+
# |   Metric |   Paper MSE |   My MSE |   Paper MAE |   My MAE |
# +==========+=============+==========+=============+==========+
# |       24 |       0.098 | 0.143411 |       0.247 | 0.322629 |
# +----------+-------------+----------+-------------+----------+
# |       48 |       0.158 | 0.186917 |       0.319 | 0.366593 |
# +----------+-------------+----------+-------------+----------+

# %%
# Load predictions and ground truth
preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

preds.shape, trues.shape
# Out:
# ((2816, 48, 1), (2816, 48, 1))

# %%
# Visualize prediction against ground truth
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# Update args
args.data = 'ETTm2'
args.data_path = 'ETTm2.csv'
args.pred_len = 24

# %%
# Update data parser for the new dataset
data_parser = {
    'ETTm2':{'data':'ETTm2.csv','T':'OT','M':[1,1,1],'S':[1,1,1],'MS':[1,1,1]},
}

# Update args based on the new dataset
if args.data in data_parser.keys():
    data_info = data_parser[args.data]
    args.data_path = data_info['data']
    args.target = data_info['T']
    args.enc_in, args.dec_in, args.c_out = data_info[args.features]

# %%
# Update frequency details and frequency
args.detail_freq = args.freq
args.freq = args.freq[-1:]

# %%
# Print experiment parameters
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'ETTm2', 'root_path': './ETDataset/ETT-small/', 'data_path': 'ETTm2.csv', 'features': 'S', 'target': 'OT', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 96, 'label_len': 48, 'pred_len': 24, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 32, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': True, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}

# %%
# Define the Experiment class as Exp
Exp = Exp_Informer

# %%
# Lists to store MSE and MAE values
mse_values = []
mae_values = []

# %%
# Iterate over multiple experiments
for ii in range(args.itr):
    setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}'.format(args.model, args.data, args.features,
                args.seq_len, args.label_len, args.pred_len,
                args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii)

    # Create an instance of Exp with args
    exp = Exp(args)

    # Training phase
    print(f'---------------------- Start training: {setting} ---------------------->')
    exp.train(setting)

    # Testing phase
    print(f'---------------------- Testing: {setting} ----------------------')
    exp.test(setting)

    torch.cuda.empty_cache()
# Out:
# Use GPU: cuda:0
# ---------------------- Start training: informer_ETTm2_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ---------------------->
# train 34441
# val 11497
# test 11497
# 	iters: 100, epoch: 1 | loss: 0.1079739
# 	speed: 0.0733s/iter; left time: 465.9792s
# 	iters: 200, epoch: 1 | loss: 0.1137088
# 	speed: 0.0736s/iter; left time: 460.3484s
# 	iters: 300, epoch: 1 | loss: 0.1195856
# 	speed: 0.0740s/iter; left time: 455.9185s
# 	iters: 400, epoch: 1 | loss: 0.0276692
# 	speed: 0.0735s/iter; left time: 445.1869s
# 	iters: 500, epoch: 1 | loss: 0.0558373
# 	speed: 0.0743s/iter; left time: 442.5289s
# 	iters: 600, epoch: 1 | loss: 0.1049192
# 	speed: 0.0740s/iter; left time: 433.6291s
# 	iters: 700, epoch: 1 | loss: 0.0280523
# 	speed: 0.0738s/iter; left time: 424.9831s
# 	iters: 800, epoch: 1 | loss: 0.0595997
# 	speed: 0.0741s/iter; left time: 419.4545s
# 	iters: 900, epoch: 1 | loss: 0.0445924
# 	speed: 0.0736s/iter; left time: 409.0304s
# 	iters: 1000, epoch: 1 | loss: 0.0296256
# 	speed: 0.0739s/iter; left time: 403.4458s
# Epoch: 1 cost time: 79.46534514427185
# Epoch: 1, Steps: 1076 | Train Loss: 0.0719868 Vali Loss: 0.0312191 Test Loss: 0.0305769
# Validation loss decreased (inf --> 0.031219).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# ---------------------- Testing: informer_ETTm2_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ----------------------
# test 11497
# test shape: (359, 32, 24, 1) (359, 32, 24, 1)
# test shape: (11488, 24, 1) (11488, 24, 1)
# mse:0.02471192181110382, mae:0.11470044404268265

# %%
import os

# Load a specific experiment setting for prediction
setting = 'informer_ETTm2_ftS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'

# %%
exp = Exp(args)

# Generate predictions for the loaded setting
exp.predict(setting, True)
# Out:
# Use GPU: cuda:0
# pred 1

# %%
# Import necessary libraries for plotting
import numpy as np
import matplotlib.pyplot as plt

# Load metrics for the specified setting
metrics_path = './results/' + setting + '/metrics.npy'
metrics = np.load(metrics_path)

# Append metrics values to respective lists
mae_values.append(metrics[0])
mse_values.append(metrics[1])

# Load real predictions for plotting
prediction = np.load('./results/'+setting+'/real_prediction.npy')
prediction.shape

# Plot predictions
plt.figure()
plt.plot(prediction[0, :, -1])
plt.show()

# %%
# Define a function to generate predictions
def predict(exp, setting, load=False):
    pred_data, pred_loader = exp._get_data(flag='pred')

    # Load the best model if specified
    if load:
        path = os.path.join(exp.args.checkpoints, setting)
        best_model_path = path+'/'+'checkpoint.pth'
        exp.model.load_state_dict(torch.load(best_model_path))

    # Set the model to evaluation mode
    exp.model.eval()

    preds = []

    # Iterate over prediction loader
    for i, (batch_x,batch_y,batch_x_mark,batch_y_mark) in enumerate(pred_loader):
        batch_x = batch_x.float().to(exp.device)
        batch_y = batch_y.float()
        batch_x_mark = batch_x_mark.float().to(exp.device)
        batch_y_mark = batch_y_mark.float().to(exp.device)

        # Define the decoding input based on padding
        if exp.args.padding==0:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        elif exp.args.padding==1:
            dec_inp = torch.ones([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        else:
            dec_inp = torch.zeros([batch_y.shape[0], exp.args.pred_len, batch_y.shape[-1]]).float()
        dec_inp = torch.cat([batch_y[:,:exp.args.label_len,:], dec_inp], dim=1).float().to(exp.device)

        # Apply automatic mixed precision if specified
        if exp.args.use_amp:
            with torch.cuda.amp.autocast():
                if exp.args.output_attention:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
                else:
                    outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
        else:
            if exp.args.output_attention:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)[0]
            else:
                outputs = exp.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)

        # Extract target dimensions based on features
        f_dim = -1 if exp.args.features=='MS' else 0
        batch_y = batch_y[:,-exp.args.pred_len:,f_dim:].to(exp.device)

        # Convert predictions to numpy array
        pred = outputs.detach().cpu().numpy()#.squeeze()

        # Append predictions to the list
        preds.append(pred)

    # Convert predictions to numpy array and reshape
    preds = np.array(preds)
    preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])

    # Define folder path to store predictions
    folder_path = './results/' + setting +'/'
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Save real predictions to a file
    np.save(folder_path+'real_prediction.npy', preds)

    return preds

# %%
# Generate predictions for a specific setting
prediction = predict(exp, setting, True)
# Out:
# pred 1

# %%
import matplotlib.pyplot as plt

# Plot predictions
plt.figure()
plt.plot(prediction[0,:,-1])
plt.show()

# %%
# Import necessary modules for data loading
from data.data_loader import Dataset_Pred
from torch.utils.data import DataLoader

# %%
# Define data set and data loader for prediction
Data = Dataset_Pred
timeenc = 0 if args.embed!='timeF' else 1
flag = 'pred'; shuffle_flag = False; drop_last = False; batch_size = 1

freq = args.detail_freq

data_set = Data(
    root_path=args.root_path,
    data_path=args.data_path,
    flag=flag,
    size=[args.seq_len, args.label_len, args.pred_len],
    features=args.features,
    target=args.target,
    timeenc=timeenc,
    freq=freq
)

data_loader = DataLoader(
    data_set,
    batch_size=batch_size,
    shuffle=shuffle_flag,
    num_workers=args.num_workers,
    drop_last=drop_last)

# %%
# Print lengths of data set and data loader
len(data_set), len(data_loader)
# Out:
# (1, 1)

# %%
# Load predictions and ground truth values
preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

# Print shapes of predictions and ground truth
preds.shape, trues.shape
# Out:
# ((11488, 24, 1), (11488, 24, 1))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Draw OT prediction
plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()

# %%
# Draw HUFL prediction
plt.figure()
plt.plot(trues[0,:,0], label='GroundTruth')
plt.plot(preds[0,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Load predictions for the current setting and plot
exp.predict(setting, True)
prediction = np.load('./results/' + setting + '/real_prediction.npy')

# Plot predictions
plt.figure()
plt.plot(prediction[0, :, -1])
plt.show()
# Out:
# pred 1

# %%
# Update prediction length
args.pred_len = 48

# Define data parser for specific datasets
data_parser = {
    'ETTm2':{'data':'ETTm2.csv','T':'OT','M':[1,1,1],'S':[1,1,1],'MS':[1,1,1]},
}

# Update args based on selected dataset
if args.data in data_parser.keys():
    data_info = data_parser[args.data]
    args.data_path = data_info['data']
    args.target = data_info['T']
    args.enc_in, args.dec_in, args.c_out = data_info[args.features]

# Store original frequency and update it
args.detail_freq = args.freq
args.freq = args.freq[-1:]

# Print experiment parameters
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'ETTm2', 'root_path': './ETDataset/ETT-small/', 'data_path': 'ETTm2.csv', 'features': 'S', 'target': 'OT', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 96, 'label_len': 48, 'pred_len': 48, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'mix': True, 'padding': 0, 'batch_size': 32, 'learning_rate': 0.0001, 'loss': 'mse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': True, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}

# %%
# Define the Experiment class as Exp
Exp = Exp_Informer

# %%
# Iterate over multiple experiments
for ii in range(args.itr):
    setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_mx{}_{}_{}'.format(args.model, args.data, args.features,
                args.seq_len, args.label_len, args.pred_len,
                args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.mix, args.des, ii)

    # Create an instance of Exp with args
    exp = Exp(args)

    # Training phase
    print(f'---------------------- Start training: {setting} ---------------------->')
    exp.train(setting)

    # Testing phase
    print(f'---------------------- Testing: {setting} ----------------------')
    exp.test(setting)

    torch.cuda.empty_cache()
# Out:
# Use GPU: cuda:0
# ---------------------- Start training: informer_ETTm2_ftS_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.0391907
# 	speed: 0.3603s/iter; left time: 351.6750s
# 	iters: 200, epoch: 6 | loss: 0.0252018
# 	speed: 0.0807s/iter; left time: 70.6643s
# 	iters: 300, epoch: 6 | loss: 0.0149697
# 	speed: 0.0806s/iter; left time: 62.5749s
# 	iters: 400, epoch: 6 | loss: 0.0190176
# 	speed: 0.0809s/iter; left time: 54.6860s
# 	iters: 500, epoch: 6 | loss: 0.0184447
# 	speed: 0.0803s/iter; left time: 46.2770s
# 	iters: 600, epoch: 6 | loss: 0.0189973
# 	speed: 0.0807s/iter; left time: 38.4016s
# 	iters: 700, epoch: 6 | loss: 0.0227033
# 	speed: 0.0809s/iter; left time: 30.4010s
# 	iters: 800, epoch: 6 | loss: 0.0214241
# 	speed: 0.0810s/iter; left time: 22.3467s
# 	iters: 900, epoch: 6 | loss: 0.0208295
# 	speed: 0.0808s/iter; left time: 14.2211s
# 	iters: 1000, epoch: 6 | loss: 0.0319669
# 	speed: 0.0811s/iter; left time: 6.1609s
# Epoch: 6 cost time: 86.83781409263611
# Epoch: 6, Steps: 1075 | Train Loss: 0.0245730 Vali Loss: 0.0587237 Test Loss: 0.0494926
# EarlyStopping counter: 3 out of 3
# Early stopping
# ---------------------- Testing: informer_ETTm2_ftS_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0 ----------------------
# test 11473
# test shape: (358, 32, 48, 1) (358, 32, 48, 1)
# test shape: (11456, 48, 1) (11456, 48, 1)
# mse:0.05284564197063446, mae:0.17084768414497375

# %%
import os

# Load a specific experiment setting for prediction
setting = 'informer_ETTm2_ftS_sl96_ll48_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_exp_0'

# %%
exp = Exp(args)

# Generate predictions for the loaded setting
exp.predict(setting, True)
# Out:
# Use GPU: cuda:0
# pred 1

# %%
# Import necessary libraries for plotting
import numpy as np
import matplotlib.pyplot as plt

# Load metrics for the specified setting
metrics_path = './results/' + setting + '/metrics.npy'
metrics = np.load(metrics_path)

# Append metrics values to respective lists
mae_values.append(metrics[0])
mse_values.append(metrics[1])

# Load real predictions for plotting
prediction = np.load('./results/'+setting+'/real_prediction.npy')
prediction.shape

# Plot predictions
plt.figure()
plt.plot(prediction[0, :, -1])
plt.show()

# %%
# Display the results in a table
from tabulate import tabulate

# Print the dataset name
print(args.data)
time_intervals = [24, 48]

# Define paper metrics values for comparison
paper_mse_values = [0.030, 0.069]
paper_mae_values = [0.137, 0.203]

# Create a table with metric values for both paper and the current experiment
data = [
    ["Metric", "Paper MSE", "My MSE", "Paper MAE", "My MAE"],
    [time_intervals[0], paper_mse_values[0], mse_values[0], paper_mae_values[0], mae_values[0]],
    [time_intervals[1], paper_mse_values[1], mse_values[1], paper_mae_values[1], mae_values[1]],
]

# Generate the table with headers and specified format
table = tabulate(data, headers="firstrow", tablefmt="grid")
print(table)
# Out:
# ETTm2
# +----------+-------------+-----------+-------------+----------+
# |   Metric |   Paper MSE |    My MSE |   Paper MAE |   My MAE |
# +==========+=============+===========+=============+==========+
# |       24 |       0.03  | 0.0247119 |       0.137 | 0.1147   |
# +----------+-------------+-----------+-------------+----------+
# |       48 |       0.069 | 0.0528456 |       0.203 | 0.170848 |
# +----------+-------------+-----------+-------------+----------+

# %%
# Load predictions and ground truth
preds = np.load('./results/'+setting+'/pred.npy')
trues = np.load('./results/'+setting+'/true.npy')

preds.shape, trues.shape
# Out:
# ((11456, 48, 1), (11456, 48, 1))

# %%
# Visualize prediction against ground truth
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure()
plt.plot(trues[0,:,-1], label='GroundTruth')
plt.plot(preds[0,:,-1], label='Prediction')
plt.legend()
plt.show()
